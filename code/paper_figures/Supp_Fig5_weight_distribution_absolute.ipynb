# %%
import os
import sys

repository_path = "/Users/user/Downloads/sift2_unbiased/"
functions_path  = os.path.join(repository_path, "code", "paper_figures", "functions")
sys.path.append(os.path.abspath(functions_path))

from extract_absolute_weights import extract_absolute_weights

# %%
reg_bases_abs = ["streamline","fixel","group"]
reg_fns_abs = ["coefficient","factor", "gamma"]
reg_strengths_abs = [1.0e-12, 1.0e-09, 1.0e-06, 1.0e-05, 1.0e-04, 1.0e-03, 1.0e-02, 1.0e-01, 1.0e+00, 1.0e+01, 2.5e+01, 5.0e+01, 1.0e+02, 2.5e+02, 5.0e+02, 1.0e+03, 2.5e+03, 5.0e+03, 1.0e+04, 2.5e+04, 5.0e+04]

# %% [markdown]
# # PHANTOM

# %%
phantom = "disco3_central_lesion_snr20" # "disco3_single_bundle_snr20 (results need to be generated)" "disco3_crossing_bundles_snr20 (results need to be generated)" "disco3_central_lesion_snr20"
tcks_phantom = "tracks" # file name of tracks 
phantom_path = os.path.join(repository_path,"data","phantoms",phantom) # Define phantom path
out_path = "/users/user/Downloads/weights_absolute/phantom" # Define output path
ylim=(0,1.1)

# %% [markdown]
# ### Coefficient

# %%
sift = "sift2_template"
dfs = []
reg_fn_abs = "coefficient"
 
for reg_basis_abs in reg_bases_abs:
        print(reg_basis_abs)
        for strength in reg_strengths_abs: 
            extract_absolute_weights(phantom_path,tcks_phantom,reg_basis_abs,reg_fn_abs,strength,histogram=True,xlim=(0,5),extract="weights",save_png=os.path.join(out_path,reg_basis_abs,"coefficient"))
            #extract_absolute_weights(phantom_path,tcks_phantom,reg_basis_abs,strength,histogram=True,xlim=(0,5),extract="coeffs")

# %% [markdown]
# ### Factor

# %%
sift = "sift2_template"
dfs = []
reg_fn_abs = "factor"
 
for reg_basis_abs in reg_bases_abs:
        print(reg_basis_abs)
        for strength in reg_strengths_abs: 
            extract_absolute_weights(phantom_path,tcks_phantom,reg_basis_abs,reg_fn_abs,strength,histogram=True,xlim=(0,5),extract="weights",save_png=os.path.join(out_path,reg_basis_abs,"factor"))
            #extract_absolute_weights(phantom_path,tcks_phantom,reg_basis_abs,strength,histogram=True,xlim=(0,5),extract="coeffs")

# %% [markdown]
# ### GAMMA

# %%
sift = "sift2_template"
dfs = []
reg_fn_abs = "gamma"
 
for reg_basis_abs in reg_bases_abs:
        print(reg_basis_abs)
        for strength in reg_strengths_abs: 
            extract_absolute_weights(phantom_path,tcks_phantom,reg_basis_abs,reg_fn_abs,strength,histogram=True,xlim=(0,5),extract="weights",save_png=os.path.join(out_path,reg_basis_abs,"gamma"))
            #extract_absolute_weights(phantom_path,tcks_phantom,reg_basis_abs,strength,histogram=True,xlim=(0,5),extract="coeffs")

# %% [markdown]
# # IN VIVO

# %%
in_vivo_sub_path = os.path.join(repository_path,"data","in_vivo","Lcurve_subject")
out_path = "/users/user/Downloads/weights_absolute/in_vivo" # Define output path
tcks_in_vivo = "tracks_100k_template"
ylim=(0,1.1)

# %% [markdown]
# ### COEFFICIENT

# %%
sift = "sift2_template"
dfs = []
reg_fn_abs = "coefficient"
 
for reg_basis_abs in reg_bases_abs:
        print(reg_basis_abs)
        for strength in reg_strengths_abs: 
            extract_absolute_weights(in_vivo_sub_path,tcks_in_vivo,reg_basis_abs,reg_fn_abs,strength,histogram=True,xlim=(0,5),extract="weights",save_png=os.path.join(out_path,reg_basis_abs,"coefficient"))
            #extract_absolute_weights(in_vivo_sub_path,tcks_in_vivo,reg_basis_abs,strength,histogram=True,xlim=(0,5),extract="coeffs")

# %% [markdown]
# ### FACTOR

# %%
sift = "sift2_template"
dfs = []
reg_fn_abs = "factor"
 
for reg_basis_abs in reg_bases_abs:
        print(reg_basis_abs)
        for strength in reg_strengths_abs: 
            extract_absolute_weights(in_vivo_sub_path,tcks_in_vivo,reg_basis_abs,reg_fn_abs,strength,histogram=True,xlim=(0,5),extract="weights",save_png=os.path.join(out_path,reg_basis_abs,"factor"))
            #extract_absolute_weights(in_vivo_sub_path,tcks_in_vivo,reg_basis_abs,strength,histogram=True,xlim=(0,5),extract="coeffs")

# %% [markdown]
# ### GAMMA

# %%
sift = "sift2_template"
dfs = []
reg_fn_abs = "gamma"
 
for reg_basis_abs in reg_bases_abs:
        print(reg_basis_abs)
        for strength in reg_strengths_abs: 
            extract_absolute_weights(in_vivo_sub_path,tcks_in_vivo,reg_basis_abs,reg_fn_abs,strength,histogram=True,xlim=(0,5),extract="weights",save_png=os.path.join(out_path,reg_basis_abs,"gamma"))
            #extract_absolute_weights(in_vivo_sub_path,tcks_in_vivo,reg_basis_abs,strength,histogram=True,xlim=(0,5),extract="coeffs")
